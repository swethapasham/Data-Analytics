# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\neeha\\OneDrive\\Desktop'

# %%
os.chdir('C:/Users/neeha/OneDrive/Desktop/')

# %%
os.getcwd()
# Out:
# 'C:\\Users\\neeha\\OneDrive\\Desktop'

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
get_ipython().run_line_magic('matplotlib', 'inline')
import seaborn as sns
data9=pd.read_csv("forestfires.csv")
data9
# Out:
#      X  Y month  day  FFMC    DMC     DC   ISI  temp  RH  wind  rain   area
# 0    7  5   mar  fri  86.2   26.2   94.3   5.1   8.2  51   6.7   0.0   0.00
# 1    7  4   oct  tue  90.6   35.4  669.1   6.7  18.0  33   0.9   0.0   0.00
# 2    7  4   oct  sat  90.6   43.7  686.9   6.7  14.6  33   1.3   0.0   0.00
# 3    8  6   mar  fri  91.7   33.3   77.5   9.0   8.3  97   4.0   0.2   0.00
# 4    8  6   mar  sun  89.3   51.3  102.2   9.6  11.4  99   1.8   0.0   0.00
# 5    8  6   aug  sun  92.3   85.3  488.0  14.7  22.2  29   5.4   0.0   0.00
# 6    8  6   aug  mon  92.3   88.9  495.6   8.5  24.1  27   3.1   0.0   0.00
# 7    8  6   aug  mon  91.5  145.4  608.2  10.7   8.0  86   2.2   0.0   0.00
# 8    8  6   sep  tue  91.0  129.5  692.6   7.0  13.1  63   5.4   0.0   0.00
# 9    7  5   sep  sat  92.5   88.0  698.6   7.1  22.8  40   4.0   0.0   0.00
# 10   7  5   sep  sat  92.5   88.0  698.6   7.1  17.8  51   7.2   0.0   0.00
# ...

# %%
data9.area.value_counts()
# Out:
# 0.00     247
# 1.94       3
# 3.71       2
# 0.90       2
# 1.95       2
# 2.14       2
# 2.18       2
# 1.56       2
# 9.96       2
# 28.66      2
# 1.46       2
# 0.68       2
# 0.43       2
# 1.64       2
# 6.43       2
# 9.27       2
# 0.52       2
# 1.75       2
# 11.06      2
# 1.63       2
# 17.20      1
# 48.55      1
# 0.95       1
# 0.77       1
# 11.19      1
# 15.64      1
# 2.64       1
# 3.52       1
# 38.48      1
# 5.39       1
#         ...
# 1.61       1
# 1.07       1
# 6.38       1
# 5.86       1
# 3.19       1
# 11.16      1
# 8.85       1
# 86.45      1
# 5.18       1
# 30.18      1
# 2.01       1
# 1.01       1
# 20.03      1
# 0.79       1
# 49.59      1
# 4.41       1
# 7.02       1
# 0.71       1
# 9.41       1
# 0.09       1
# 3.32       1
# 11.53      1
# 5.55       1
# 3.20       1
# 4.88       1
# 1.26       1
# 2.44       1
# 2.03       1
# 2.21       1
# 24.24      1
# Name: area, Length: 251, dtype: int64

# %%
data9
# Out:
#      X  Y month  day  FFMC    DMC     DC   ISI  temp  RH  wind  rain   area
# 0    7  5   mar  fri  86.2   26.2   94.3   5.1   8.2  51   6.7   0.0   0.00
# 1    7  4   oct  tue  90.6   35.4  669.1   6.7  18.0  33   0.9   0.0   0.00
# 2    7  4   oct  sat  90.6   43.7  686.9   6.7  14.6  33   1.3   0.0   0.00
# 3    8  6   mar  fri  91.7   33.3   77.5   9.0   8.3  97   4.0   0.2   0.00
# 4    8  6   mar  sun  89.3   51.3  102.2   9.6  11.4  99   1.8   0.0   0.00
# 5    8  6   aug  sun  92.3   85.3  488.0  14.7  22.2  29   5.4   0.0   0.00
# 6    8  6   aug  mon  92.3   88.9  495.6   8.5  24.1  27   3.1   0.0   0.00
# 7    8  6   aug  mon  91.5  145.4  608.2  10.7   8.0  86   2.2   0.0   0.00
# 8    8  6   sep  tue  91.0  129.5  692.6   7.0  13.1  63   5.4   0.0   0.00
# 9    7  5   sep  sat  92.5   88.0  698.6   7.1  22.8  40   4.0   0.0   0.00
# 10   7  5   sep  sat  92.5   88.0  698.6   7.1  17.8  51   7.2   0.0   0.00
# ...

# %%
x=data9.iloc[:,[8,10]]
y=data9.iloc[:,12]

# %%
k=data9.iloc[:,[8,9]]
l=data9.iloc[:,12]

# %%
k
# Out:
#      temp  RH
# 0     8.2  51
# 1    18.0  33
# 2    14.6  33
# 3     8.3  97
# 4    11.4  99
# 5    22.2  29
# 6    24.1  27
# 7     8.0  86
# 8    13.1  63
# 9    22.8  40
# 10   17.8  51
# 11   19.3  38
# 12   17.0  72
# 13   21.3  42
# 14   26.4  21
# 15   22.9  44
# 16   15.1  27
# 17   16.7  47
# 18   15.9  35
# 19    9.3  44
# 20   18.3  40
# 21   19.1  38
# 22   21.0  44
# 23   19.5  43
# 24   23.7  32
# 25   16.3  60
# 26   19.0  34
# 27   19.4  48
# 28   30.2  24
# 29   22.8  39
# ..    ...  ..
# 487  26.4  34
# 488  19.4  71
# 489  20.6  58
# 490  28.7  33
# 491  32.4  21
# 492  32.4  27
# 493  27.5  29
# 494  30.8  30
# 495  23.9  42
# 496  32.6  26
# 497  32.3  27
# 498  33.3  26
# 499  27.3  63
# 500  21.6  65
# 501  21.6  65
# 502  20.7  69
# 503  29.2  30
# 504  28.9  29
# 505  26.7  35
# 506  18.5  73
# 507  25.9  41
# 508  25.9  41
# 509  21.1  71
# 510  18.2  62
# 511  27.8  35
# 512  27.8  32
# 513  21.9  71
# 514  21.2  70
# 515  25.6  42
# 516  11.8  31
#
# ...

# %%
l
# Out:
# 0       0.00
# 1       0.00
# 2       0.00
# 3       0.00
# 4       0.00
# 5       0.00
# 6       0.00
# 7       0.00
# 8       0.00
# 9       0.00
# 10      0.00
# 11      0.00
# 12      0.00
# 13      0.00
# 14      0.00
# 15      0.00
# 16      0.00
# 17      0.00
# 18      0.00
# 19      0.00
# 20      0.00
# 21      0.00
# 22      0.00
# 23      0.00
# 24      0.00
# 25      0.00
# 26      0.00
# 27      0.00
# 28      0.00
# 29      0.00
#        ...
# 487    16.40
# 488    46.70
# 489     0.00
# 490     0.00
# 491     0.00
# 492     0.00
# 493    43.32
# 494     8.59
# 495     0.00
# 496     2.77
# 497    14.68
# 498    40.54
# 499    10.82
# 500     0.00
# 501     0.00
# 502     0.00
# 503     1.95
# 504    49.59
# 505     5.80
# 506     0.00
# 507     0.00
# 508     0.00
# 509     2.17
# 510     0.43
# 511     0.00
# 512     6.44
# 513    54.29
# 514    11.16
# 515     0.00
# 516     0.00
# Name: area, Length: 517, dtype: float64

# %%
x
# Out:
#      temp  wind
# 0     8.2   6.7
# 1    18.0   0.9
# 2    14.6   1.3
# 3     8.3   4.0
# 4    11.4   1.8
# 5    22.2   5.4
# 6    24.1   3.1
# 7     8.0   2.2
# 8    13.1   5.4
# 9    22.8   4.0
# 10   17.8   7.2
# 11   19.3   4.0
# 12   17.0   6.7
# 13   21.3   2.2
# 14   26.4   4.5
# 15   22.9   5.4
# 16   15.1   5.4
# 17   16.7   4.9
# 18   15.9   4.0
# 19    9.3   4.5
# 20   18.3   2.7
# 21   19.1   2.7
# 22   21.0   4.5
# 23   19.5   5.8
# 24   23.7   5.8
# 25   16.3   5.4
# 26   19.0   5.8
# 27   19.4   1.3
# 28   30.2   2.7
# 29   22.8   3.6
# ..    ...   ...
# 487  26.4   3.6
# 488  19.4   7.6
# 489  20.6   1.3
# 490  28.7   4.0
# 491  32.4   4.5
# 492  32.4   2.2
# 493  27.5   4.5
# 494  30.8   4.9
# 495  23.9   2.2
# 496  32.6   3.1
# 497  32.3   2.2
# 498  33.3   2.7
# 499  27.3   4.9
# 500  21.6   4.9
# 501  21.6   4.9
# 502  20.7   4.9
# 503  29.2   4.9
# 504  28.9   4.9
# 505  26.7   1.8
# 506  18.5   8.5
# 507  25.9   3.6
# 508  25.9   3.6
# 509  21.1   7.6
# ...

# %%
y
# Out:
# 0       0.00
# 1       0.00
# 2       0.00
# 3       0.00
# 4       0.00
# 5       0.00
# 6       0.00
# 7       0.00
# 8       0.00
# 9       0.00
# 10      0.00
# 11      0.00
# 12      0.00
# 13      0.00
# 14      0.00
# 15      0.00
# 16      0.00
# 17      0.00
# 18      0.00
# 19      0.00
# 20      0.00
# 21      0.00
# 22      0.00
# 23      0.00
# 24      0.00
# 25      0.00
# 26      0.00
# 27      0.00
# 28      0.00
# 29      0.00
#        ...
# 487    16.40
# 488    46.70
# 489     0.00
# 490     0.00
# 491     0.00
# 492     0.00
# 493    43.32
# 494     8.59
# 495     0.00
# 496     2.77
# 497    14.68
# 498    40.54
# 499    10.82
# 500     0.00
# 501     0.00
# 502     0.00
# 503     1.95
# 504    49.59
# 505     5.80
# 506     0.00
# 507     0.00
# 508     0.00
# 509     2.17
# 510     0.43
# 511     0.00
# 512     6.44
# 513    54.29
# 514    11.16
# 515     0.00
# 516     0.00
# Name: area, Length: 517, dtype: float64

# %%
#first 400 observations as training set
x_train=x[0:400]

# %%
x_train
# Out:
#      temp  wind
# 0     8.2   6.7
# 1    18.0   0.9
# 2    14.6   1.3
# 3     8.3   4.0
# 4    11.4   1.8
# 5    22.2   5.4
# 6    24.1   3.1
# 7     8.0   2.2
# 8    13.1   5.4
# 9    22.8   4.0
# 10   17.8   7.2
# 11   19.3   4.0
# 12   17.0   6.7
# 13   21.3   2.2
# 14   26.4   4.5
# 15   22.9   5.4
# 16   15.1   5.4
# 17   16.7   4.9
# 18   15.9   4.0
# 19    9.3   4.5
# 20   18.3   2.7
# 21   19.1   2.7
# 22   21.0   4.5
# 23   19.5   5.8
# 24   23.7   5.8
# 25   16.3   5.4
# 26   19.0   5.8
# 27   19.4   1.3
# 28   30.2   2.7
# 29   22.8   3.6
# ..    ...   ...
# 370  13.8   7.6
# 371  14.2   4.0
# 372  10.4   0.9
# 373  20.3   2.7
# 374  10.3   4.0
# 375  15.4   4.9
# 376  21.1   2.2
# 377  21.9   2.2
# 378   8.7   5.8
# 379   5.2   0.9
# 380  19.3   7.2
# 381  16.2   2.7
# 382  28.2   1.8
# 383  20.5   2.7
# 384  21.3   4.5
# 385  20.9   2.2
# 386  20.6   5.4
# 387  11.6   5.4
# 388  23.3   3.1
# 389  23.3   3.1
# 390   7.5   6.3
# 391  20.7   2.7
# 392  21.9   4.0
# ...

# %%
k_train=k[0:400]

# %%
k_train
# Out:
#      temp   RH
# 0     8.2   51
# 1    18.0   33
# 2    14.6   33
# 3     8.3   97
# 4    11.4   99
# 5    22.2   29
# 6    24.1   27
# 7     8.0   86
# 8    13.1   63
# 9    22.8   40
# 10   17.8   51
# 11   19.3   38
# 12   17.0   72
# 13   21.3   42
# 14   26.4   21
# 15   22.9   44
# 16   15.1   27
# 17   16.7   47
# 18   15.9   35
# 19    9.3   44
# 20   18.3   40
# 21   19.1   38
# 22   21.0   44
# 23   19.5   43
# 24   23.7   32
# 25   16.3   60
# 26   19.0   34
# 27   19.4   48
# 28   30.2   24
# 29   22.8   39
# ..    ...  ...
# 370  13.8   77
# 371  14.2   58
# 372  10.4   75
# 373  20.3   42
# 374  10.3   78
# 375  15.4   57
# 376  21.1   54
# 377  21.9   42
# 378   8.7   51
# 379   5.2  100
# 380  19.3   39
# 381  16.2   63
# 382  28.2   29
# 383  20.5   58
# 384  21.3   44
# 385  20.9   50
# 386  20.6   55
# 387  11.6   48
# 388  23.3   34
# 389  23.3   34
# 390   7.5   71
# 391  20.7   46
# 392  21.9   43
# 393  15.2   19
# 394   5.3   68
# 395  10.1   62
# ...

# %%
#last 117 as test set
x_test=x[401:517]

# %%
x_test
# Out:
#      temp  wind
# 401  22.8   4.0
# 402  25.0   4.0
# 403  21.3   3.6
# 404  21.8   2.2
# 405  27.9   2.2
# 406  17.0   4.9
# 407  14.2   4.0
# 408  19.9   3.1
# 409  23.4   5.4
# 410  14.7   2.7
# 411   8.2   9.4
# 412  22.8   4.5
# 413  26.4   3.6
# 414  24.1   4.0
# 415  27.5   4.9
# 416  26.3   3.1
# 417  13.8   5.8
# 418  24.9   5.4
# 419  24.8   4.0
# 420  26.2   4.5
# 421  30.8   4.5
# 422  29.3   3.6
# 423  22.3   4.0
# 424  26.9   3.6
# 425  20.4   2.2
# 426  20.4   2.2
# 427  27.9   2.2
# 428  26.2   5.8
# 429  24.6   4.0
# 430  19.4   3.6
# ..    ...   ...
# 487  26.4   3.6
# 488  19.4   7.6
# 489  20.6   1.3
# 490  28.7   4.0
# 491  32.4   4.5
# 492  32.4   2.2
# 493  27.5   4.5
# 494  30.8   4.9
# 495  23.9   2.2
# 496  32.6   3.1
# 497  32.3   2.2
# 498  33.3   2.7
# 499  27.3   4.9
# 500  21.6   4.9
# 501  21.6   4.9
# 502  20.7   4.9
# 503  29.2   4.9
# 504  28.9   4.9
# 505  26.7   1.8
# 506  18.5   8.5
# 507  25.9   3.6
# 508  25.9   3.6
# 509  21.1   7.6
# ...

# %%
k_test=k[401:517]

# %%
k_test
# Out:
#      temp  RH
# 401  22.8  46
# 402  25.0  36
# 403  21.3  41
# 404  21.8  34
# 405  27.9  27
# 406  17.0  67
# 407  14.2  46
# 408  19.9  44
# 409  23.4  31
# 410  14.7  42
# 411   8.2  53
# 412  22.8  27
# 413  26.4  33
# 414  24.1  50
# 415  27.5  27
# 416  26.3  39
# 417  13.8  24
# 418  24.9  42
# 419  24.8  36
# 420  26.2  36
# 421  30.8  19
# 422  29.3  27
# 423  22.3  48
# 424  26.9  31
# 425  20.4  56
# 426  20.4  56
# 427  27.9  33
# 428  26.2  34
# 429  24.6  44
# 430  19.4  45
# ..    ...  ..
# 487  26.4  34
# 488  19.4  71
# 489  20.6  58
# 490  28.7  33
# 491  32.4  21
# 492  32.4  27
# 493  27.5  29
# 494  30.8  30
# 495  23.9  42
# 496  32.6  26
# 497  32.3  27
# 498  33.3  26
# 499  27.3  63
# 500  21.6  65
# 501  21.6  65
# 502  20.7  69
# 503  29.2  30
# 504  28.9  29
# 505  26.7  35
# 506  18.5  73
# 507  25.9  41
# 508  25.9  41
# 509  21.1  71
# 510  18.2  62
# 511  27.8  35
# 512  27.8  32
# 513  21.9  71
# 514  21.2  70
# 515  25.6  42
# 516  11.8  31
#
# ...

# %%
y_train=y[0:400]

# %%
y_train
# Out:
# 0        0.00
# 1        0.00
# 2        0.00
# 3        0.00
# 4        0.00
# 5        0.00
# 6        0.00
# 7        0.00
# 8        0.00
# 9        0.00
# 10       0.00
# 11       0.00
# 12       0.00
# 13       0.00
# 14       0.00
# 15       0.00
# 16       0.00
# 17       0.00
# 18       0.00
# 19       0.00
# 20       0.00
# 21       0.00
# 22       0.00
# 23       0.00
# 24       0.00
# 25       0.00
# 26       0.00
# 27       0.00
# 28       0.00
# 29       0.00
#         ...
# 370     11.06
# 371      0.00
# 372      0.00
# 373      0.00
# 374     18.30
# 375     39.35
# 376      0.00
# 377    174.63
# 378      0.00
# 379      0.00
# 380      7.73
# 381     16.33
# 382      5.86
# 383     42.87
# 384     12.18
# 385     16.00
# 386     24.59
# 387      0.00
# 388     28.74
# 389      0.00
# 390      9.96
# 391     30.18
# 392     70.76
# 393      0.00
# 394      0.00
# 395     51.78
# 396      3.64
# 397      3.63
# 398      0.00
# 399      0.00
# ...

# %%
l_train=l[0:400]

# %%
l_train
# Out:
# 0        0.00
# 1        0.00
# 2        0.00
# 3        0.00
# 4        0.00
# 5        0.00
# 6        0.00
# 7        0.00
# 8        0.00
# 9        0.00
# 10       0.00
# 11       0.00
# 12       0.00
# 13       0.00
# 14       0.00
# 15       0.00
# 16       0.00
# 17       0.00
# 18       0.00
# 19       0.00
# 20       0.00
# 21       0.00
# 22       0.00
# 23       0.00
# 24       0.00
# 25       0.00
# 26       0.00
# 27       0.00
# 28       0.00
# 29       0.00
#         ...
# 370     11.06
# 371      0.00
# 372      0.00
# 373      0.00
# 374     18.30
# 375     39.35
# 376      0.00
# 377    174.63
# 378      0.00
# 379      0.00
# 380      7.73
# 381     16.33
# 382      5.86
# 383     42.87
# 384     12.18
# 385     16.00
# 386     24.59
# 387      0.00
# 388     28.74
# 389      0.00
# 390      9.96
# 391     30.18
# 392     70.76
# 393      0.00
# 394      0.00
# 395     51.78
# 396      3.64
# 397      3.63
# 398      0.00
# 399      0.00
# ...

# %%
y_test=y[401:517]

# %%
y_test
# Out:
# 401      4.95
# 402      0.00
# 403      0.00
# 404      6.04
# 405      0.00
# 406      3.95
# 407      0.00
# 408      7.80
# 409      0.00
# 410      0.00
# 411      4.62
# 412      1.63
# 413      0.00
# 414      0.00
# 415    746.28
# 416      7.02
# 417      0.00
# 418      2.44
# 419      3.05
# 420    185.76
# 421      0.00
# 422      6.30
# 423      0.72
# 424      4.96
# 425      0.00
# 426      0.00
# 427      2.35
# 428      0.00
# 429      3.20
# 430      0.00
#         ...
# 487     16.40
# 488     46.70
# 489      0.00
# 490      0.00
# 491      0.00
# 492      0.00
# 493     43.32
# 494      8.59
# 495      0.00
# 496      2.77
# 497     14.68
# 498     40.54
# 499     10.82
# 500      0.00
# 501      0.00
# 502      0.00
# 503      1.95
# 504     49.59
# 505      5.80
# 506      0.00
# 507      0.00
# 508      0.00
# 509      2.17
# 510      0.43
# 511      0.00
# 512      6.44
# 513     54.29
# 514     11.16
# 515      0.00
# 516      0.00
# ...

# %%
l_test=l[401:517]

# %%
l_test
# Out:
# 401      4.95
# 402      0.00
# 403      0.00
# 404      6.04
# 405      0.00
# 406      3.95
# 407      0.00
# 408      7.80
# 409      0.00
# 410      0.00
# 411      4.62
# 412      1.63
# 413      0.00
# 414      0.00
# 415    746.28
# 416      7.02
# 417      0.00
# 418      2.44
# 419      3.05
# 420    185.76
# 421      0.00
# 422      6.30
# 423      0.72
# 424      4.96
# 425      0.00
# 426      0.00
# 427      2.35
# 428      0.00
# 429      3.20
# 430      0.00
#         ...
# 487     16.40
# 488     46.70
# 489      0.00
# 490      0.00
# 491      0.00
# 492      0.00
# 493     43.32
# 494      8.59
# 495      0.00
# 496      2.77
# 497     14.68
# 498     40.54
# 499     10.82
# 500      0.00
# 501      0.00
# 502      0.00
# 503      1.95
# 504     49.59
# 505      5.80
# 506      0.00
# 507      0.00
# 508      0.00
# 509      2.17
# 510      0.43
# 511      0.00
# 512      6.44
# 513     54.29
# 514     11.16
# 515      0.00
# 516      0.00
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
import random 
get_ipython().run_line_magic('matplotlib', '')
from sklearn import datasets, linear_model
from sklearn.metrics import mean_squared_error, r2_score
liregr1 = linear_model.LinearRegression()
liregr2 = linear_model.LinearRegression()
s1=liregr1.fit(x_train, y_train)
s2=liregr2.fit(k_train, l_train)
y_predi1 = liregr1.predict(x_test)
l_predi2 = liregr2.predict(k_test)
print(" The Area burnt for temp and wind feature: %.2f"% mean_squared_error(y_test,y_predi1))
print(" The Area burnt for temp and RH feature: %.2f"% mean_squared_error(l_test,l_predi2))
ms1=mean_squared_error(y_test,y_predi1)
ms2=mean_squared_error(l_test,l_predi2)
#out of all the feature combinations - temp and wind feature combination gave the least area burnt
#temp and rh gave the next least area burnt
m1=['2 feature(temp&wind)','2feature(temp&RH)']
m2=[ms1,ms2]

sns.barplot(m1,m2)
plt.title('MSE changes with features')
plt.ylabel('MSE')
plt.xlabel('number of combinations')
plt.show()
# Out:
# Using matplotlib backend: Qt5Agg
#  The Area burnt for temp and wind feature: 5667.94
#  The Area burnt for temp and RH feature: 5677.73
